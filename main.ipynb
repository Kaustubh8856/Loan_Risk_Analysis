# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('loan_default_synthetic.csv')

# %%
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (10,6)

# %%
print("Dataset shape:", df.shape)
print("\nMissing values:\n", df.isnull().sum())

print("\nNumerical summary:\n", df.describe())
# Out:
# Dataset shape: (8000, 32)
#
# Missing values:
#  loan_id                         0
# issue_date                      0
# term_months                     0
# loan_amnt                       0
# interest_rate                   0
# grade                           0
# sub_grade                       0
# emp_length_years                0
# annual_income                   0
# dti                             0
# state                           0
# home_ownership                  0
# purpose                         0
# application_type                0
# verification_status             0
# delinq_2yrs                     0
# inq_last_6m                     0
# open_acc                        0
# revol_util                      0
# revol_bal                       0
# total_acc                       0
# earliest_credit_line_year       0
# fico_low                        0
# fico_high                       0
# pub_rec                         0
# mort_acc                        0
# ...

# %%
numeric_cols = ['loan_amnt', 'interest_rate', 'annual_income', 'dti', 
                'fico_low', 'fico_high', 'revol_util', 'revol_bal']

# Histograms
df[numeric_cols].hist(bins=30, figsize=(15,10), color='skyblue', edgecolor='black')
plt.suptitle("Distribution of Numeric Features", fontsize=16)
plt.show()

# %%
for col in numeric_cols:
    plt.figure(figsize=(10,3))
    sns.boxplot(x=df[col], color='lightgreen')
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
categorical_cols = ['grade', 'term_months', 'home_ownership', 'purpose', 'verification_status']

for col in categorical_cols:
    plt.figure(figsize=(10,4))
    sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette='Set2')
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# C:\Users\Ethan Hunt\AppData\Local\Temp\ipykernel_6024\2653253491.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette='Set2')
# C:\Users\Ethan Hunt\AppData\Local\Temp\ipykernel_6024\2653253491.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, order=df[col].value_counts().index, palette='Set2')
# C:\Users\Ethan Hunt\AppData\Local\Temp\ipykernel_6024\2653253491.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...
